# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dahlonega
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | guarapari
# Processing Record 5 of Set 1 | nar'yan-mar
# Processing Record 6 of Set 1 | altay
# Processing Record 7 of Set 1 | klaksvik
# Processing Record 8 of Set 1 | papatowai
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | chaihe
# Processing Record 11 of Set 1 | mahibadhoo
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | grytviken
# Processing Record 14 of Set 1 | iqaluit
# Processing Record 15 of Set 1 | luderitz
# Processing Record 16 of Set 1 | klyuchi
# Processing Record 17 of Set 1 | selfoss
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | dauphin
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | grand falls-windsor
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | udachny
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | ta`u
# Processing Record 26 of Set 1 | lihue
# Processing Record 27 of Set 1 | blackmans bay
# Processing Record 28 of Set 1 | harstad
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | puerto armuelles
# Processing Record 31 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 1 | new plymouth
# Processing Record 33 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 1 | tual
# Processing Record 35 of Set 1 | vilyuysk
# Processing Record 36 of Set 1 | bengkulu
# Processing Record 37 of Set 1 | happy valley-goose bay
# Processing Record 38 of Set 1 | machico
# Processing Record 39 of Set 1 | paracuru
# Processing Record 40 of Set 1 | rongelap
# Processing Record 41 of Set 1 | utrik
# Processing Record 42 of Set 1 | chul'man
# Processing Record 43 of Set 1 | usogorsk
# Processing Record 44 of Set 1 | cable beach
# City not found. Skipping...
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | whitehorse
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | el nido
# Processing Record 50 of Set 1 | atafu village
# Processing Record 0 of Set 2 | puerto ayora
# Processing Record 1 of Set 2 | enewetak
# Processing Record 2 of Set 2 | tromso
# Processing Record 3 of Set 2 | labrador city
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | wailua homesteads
# Processing Record 6 of Set 2 | fatehpur
# Processing Record 7 of Set 2 | west island
# Processing Record 8 of Set 2 | betio village
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | sinabang
# Processing Record 12 of Set 2 | dulovo
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | iquique
# Processing Record 16 of Set 2 | vorgashor
# Processing Record 17 of Set 2 | chonchi
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | karratha
# Processing Record 20 of Set 2 | puerto natales
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | san juan de miraflores
# Processing Record 23 of Set 2 | olonkinbyen
# Processing Record 24 of Set 2 | zag
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | laojunmiao
# Processing Record 27 of Set 2 | saipan
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 30 of Set 2 | keflavik
# Processing Record 31 of Set 2 | mount pearl
# Processing Record 32 of Set 2 | chust
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | yarmouth
# Processing Record 35 of Set 2 | hawaiian paradise park
# Processing Record 36 of Set 2 | tokar
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | duong dong
# Processing Record 39 of Set 2 | bandon
# Processing Record 40 of Set 2 | adamstown
# Processing Record 41 of Set 2 | tolanaro
# Processing Record 42 of Set 2 | cill airne
# Processing Record 43 of Set 2 | port shepstone
# Processing Record 44 of Set 2 | stanley
# Processing Record 45 of Set 2 | tofol
# Processing Record 46 of Set 2 | timbuktu
# Processing Record 47 of Set 2 | conception bay south
# Processing Record 48 of Set 2 | kone
# Processing Record 49 of Set 2 | altamira
# Processing Record 0 of Set 3 | nosy varika
# Processing Record 1 of Set 3 | tindouf
# Processing Record 2 of Set 3 | bom jesus
# Processing Record 3 of Set 3 | margaret river
# Processing Record 4 of Set 3 | tazacorte
# Processing Record 5 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 6 of Set 3 | laguna
# Processing Record 7 of Set 3 | broken hill
# Processing Record 8 of Set 3 | nuuk
# Processing Record 9 of Set 3 | shisui
# Processing Record 10 of Set 3 | pimentel
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | mayahi
# Processing Record 13 of Set 3 | kirensk
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | pemangkat
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | pampa
# Processing Record 18 of Set 3 | susuman
# Processing Record 19 of Set 3 | mendaha
# Processing Record 20 of Set 3 | vilyuchinsk
# Processing Record 21 of Set 3 | uturoa
# Processing Record 22 of Set 3 | barpeta road
# Processing Record 23 of Set 3 | galliano
# Processing Record 24 of Set 3 | mont-laurier
# Processing Record 25 of Set 3 | kapa'a
# Processing Record 26 of Set 3 | miandrivazo
# Processing Record 27 of Set 3 | kilindoni
# Processing Record 28 of Set 3 | abepura
# Processing Record 29 of Set 3 | kultali
# City not found. Skipping...
# Processing Record 30 of Set 3 | invercargill
# Processing Record 31 of Set 3 | darwin
# Processing Record 32 of Set 3 | murun-kuren
# Processing Record 33 of Set 3 | ulverston
# Processing Record 34 of Set 3 | rurrenabaque
# Processing Record 35 of Set 3 | iskateley
# Processing Record 36 of Set 3 | alice springs
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | caxito
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | wayne
# Processing Record 41 of Set 3 | coeur d'alene
# Processing Record 42 of Set 3 | beteza
# City not found. Skipping...
# Processing Record 43 of Set 3 | miri
# Processing Record 44 of Set 3 | whangarei
# Processing Record 45 of Set 3 | zyryanovsk
# Processing Record 46 of Set 3 | fontenay-le-comte
# Processing Record 47 of Set 3 | lazaro cardenas
# Processing Record 48 of Set 3 | murghob
# Processing Record 49 of Set 3 | tekkali
# Processing Record 0 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 1 of Set 4 | steinfeld
# Processing Record 2 of Set 4 | jiujiang
# Processing Record 3 of Set 4 | flying fish cove
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | kyzyl
# Processing Record 6 of Set 4 | ustrzyki dolne
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | weno
# Processing Record 9 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 10 of Set 4 | senanga
# Processing Record 11 of Set 4 | villa gesell
# Processing Record 12 of Set 4 | suihua
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | tevriz
# Processing Record 15 of Set 4 | haiku-pauwela
# Processing Record 16 of Set 4 | nemuro
# Processing Record 17 of Set 4 | vernon
# Processing Record 18 of Set 4 | moose jaw
# Processing Record 19 of Set 4 | moab
# Processing Record 20 of Set 4 | jutai
# Processing Record 21 of Set 4 | yamada
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | galle
# Processing Record 24 of Set 4 | anqiu
# Processing Record 25 of Set 4 | al majaridah
# Processing Record 26 of Set 4 | zaysan
# Processing Record 27 of Set 4 | falmouth
# Processing Record 28 of Set 4 | al qubbah
# Processing Record 29 of Set 4 | kayangel
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | tari
# Processing Record 32 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 4 | nova sintra
# Processing Record 34 of Set 4 | kupino
# Processing Record 35 of Set 4 | isafjordur
# Processing Record 36 of Set 4 | santa ana de yacuma
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 39 of Set 4 | longyearbyen
# Processing Record 40 of Set 4 | kapuskasing
# Processing Record 41 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 42 of Set 4 | qapqal
# City not found. Skipping...
# Processing Record 43 of Set 4 | kerikeri
# Processing Record 44 of Set 4 | aoulef
# Processing Record 45 of Set 4 | praia da vitoria
# Processing Record 46 of Set 4 | phongsali
# Processing Record 47 of Set 4 | wanning
# Processing Record 48 of Set 4 | saint-pierre
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 0 of Set 5 | afaahiti
# Processing Record 1 of Set 5 | mpanda
# Processing Record 2 of Set 5 | tughyl
# Processing Record 3 of Set 5 | goias
# Processing Record 4 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | luganville
# Processing Record 7 of Set 5 | norton shores
# Processing Record 8 of Set 5 | barcelos
# Processing Record 9 of Set 5 | kodinsk
# Processing Record 10 of Set 5 | thompson
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | cabinda
# Processing Record 13 of Set 5 | hermanus
# Processing Record 14 of Set 5 | mil'kovo
# Processing Record 15 of Set 5 | shimoda
# Processing Record 16 of Set 5 | rafah
# Processing Record 17 of Set 5 | malango
# Processing Record 18 of Set 5 | chernyshevskiy
# Processing Record 19 of Set 5 | zhigalovo
# Processing Record 20 of Set 5 | touros
# Processing Record 21 of Set 5 | brookings
# Processing Record 22 of Set 5 | aitape
# Processing Record 23 of Set 5 | yuzhno-kurilsk
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | nushki
# Processing Record 26 of Set 5 | bamboo flat
# Processing Record 27 of Set 5 | puerto supe
# Processing Record 28 of Set 5 | macau
# Processing Record 29 of Set 5 | farshut
# Processing Record 30 of Set 5 | shakiso
# Processing Record 31 of Set 5 | kuusamo
# Processing Record 32 of Set 5 | port douglas
# Processing Record 33 of Set 5 | port alfred
# Processing Record 34 of Set 5 | ust'-ilimsk
# Processing Record 35 of Set 5 | kingston
# Processing Record 36 of Set 5 | kilifi
# Processing Record 37 of Set 5 | mizan teferi
# Processing Record 38 of Set 5 | nikel
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | antofagasta
# Processing Record 41 of Set 5 | paradera
# City not found. Skipping...
# Processing Record 42 of Set 5 | gizo
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | remire-montjoly
# Processing Record 45 of Set 5 | midvagur
# Processing Record 46 of Set 5 | zaltan
# Processing Record 47 of Set 5 | zimovniki
# Processing Record 48 of Set 5 | queenstown
# Processing Record 49 of Set 5 | olyokminsk
# Processing Record 0 of Set 6 | badger
# Processing Record 1 of Set 6 | barkly west
# Processing Record 2 of Set 6 | port mathurin
# Processing Record 3 of Set 6 | tralee
# Processing Record 4 of Set 6 | checker hall
# City not found. Skipping...
# Processing Record 5 of Set 6 | chilecito
# Processing Record 6 of Set 6 | boa vista
# Processing Record 7 of Set 6 | kovdor
# Processing Record 8 of Set 6 | sosnovo-ozerskoye
# Processing Record 9 of Set 6 | tucuma
# Processing Record 10 of Set 6 | carutapera
# Processing Record 11 of Set 6 | goroka
# Processing Record 12 of Set 6 | karpenisi
# Processing Record 13 of Set 6 | bowen
# Processing Record 14 of Set 6 | sant antoni de portmany
# Processing Record 15 of Set 6 | yeppoon
# Processing Record 16 of Set 6 | churapcha
# Processing Record 17 of Set 6 | kiunga
# Processing Record 18 of Set 6 | mount isa
# Processing Record 19 of Set 6 | thinadhoo
# Processing Record 20 of Set 6 | luleburgaz
# Processing Record 21 of Set 6 | amos
# Processing Record 22 of Set 6 | tazovsky
# Processing Record 23 of Set 6 | kaa-khem
# Processing Record 24 of Set 6 | bardai
# Processing Record 25 of Set 6 | lerwick
# Processing Record 26 of Set 6 | livingston
# Processing Record 27 of Set 6 | attapeu
# Processing Record 28 of Set 6 | howrah
# Processing Record 29 of Set 6 | tynda
# Processing Record 30 of Set 6 | ujae
# Processing Record 31 of Set 6 | porto de moz
# Processing Record 32 of Set 6 | kuala belait
# Processing Record 33 of Set 6 | prineville
# Processing Record 34 of Set 6 | pangody
# Processing Record 35 of Set 6 | lospalos
# Processing Record 36 of Set 6 | villa yapacani
# Processing Record 37 of Set 6 | klaeng
# Processing Record 38 of Set 6 | bazarnyye mataki
# Processing Record 39 of Set 6 | san luis de la loma
# Processing Record 40 of Set 6 | amahai
# Processing Record 41 of Set 6 | mirny
# Processing Record 42 of Set 6 | berekum
# Processing Record 43 of Set 6 | alaghsas
# Processing Record 44 of Set 6 | saudarkrokur
# Processing Record 45 of Set 6 | pokhara
# Processing Record 46 of Set 6 | arraial do cabo
# Processing Record 47 of Set 6 | newport
# Processing Record 48 of Set 6 | khorixas
# Processing Record 49 of Set 6 | khanty-mansiysk
# Processing Record 0 of Set 7 | meulaboh
# Processing Record 1 of Set 7 | svetlyy
# Processing Record 2 of Set 7 | anadyr
# Processing Record 3 of Set 7 | polyarnyy
# Processing Record 4 of Set 7 | ribadesella
# Processing Record 5 of Set 7 | newman
# Processing Record 6 of Set 7 | aldinga beach
# Processing Record 7 of Set 7 | wajir
# Processing Record 8 of Set 7 | ola
# Processing Record 9 of Set 7 | lhasa
# Processing Record 10 of Set 7 | thal
# Processing Record 11 of Set 7 | mandapam
# Processing Record 12 of Set 7 | tataouine
# Processing Record 13 of Set 7 | lebu
# Processing Record 14 of Set 7 | princeville
# Processing Record 15 of Set 7 | al qadarif
# Processing Record 16 of Set 7 | fukuecho
# Processing Record 17 of Set 7 | bad berleburg
# Processing Record 18 of Set 7 | madera
# Processing Record 19 of Set 7 | es castell
# Processing Record 20 of Set 7 | sturgis
# Processing Record 21 of Set 7 | long beach
# Processing Record 22 of Set 7 | tarfaya
# Processing Record 23 of Set 7 | magadan
# Processing Record 24 of Set 7 | anshun
# Processing Record 25 of Set 7 | gaspe
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | ugoofaaru
# Processing Record 28 of Set 7 | taro
# Processing Record 29 of Set 7 | igarka
# Processing Record 30 of Set 7 | pierre
# Processing Record 31 of Set 7 | chon daen
# Processing Record 32 of Set 7 | weyburn
# Processing Record 33 of Set 7 | minas de marcona
# Processing Record 34 of Set 7 | bayganin
# Processing Record 35 of Set 7 | sungai penuh
# Processing Record 36 of Set 7 | hithadhoo
# Processing Record 37 of Set 7 | codrington
# Processing Record 38 of Set 7 | cat ba
# City not found. Skipping...
# Processing Record 39 of Set 7 | malvan
# Processing Record 40 of Set 7 | zavodoukovsk
# Processing Record 41 of Set 7 | illizi
# Processing Record 42 of Set 7 | ginir
# Processing Record 43 of Set 7 | geraldton
# Processing Record 44 of Set 7 | morehead city
# Processing Record 45 of Set 7 | badnawar
# Processing Record 46 of Set 7 | sao vicente
# Processing Record 47 of Set 7 | lloydminster
# Processing Record 48 of Set 7 | sal rei
# Processing Record 49 of Set 7 | yucheng
# Processing Record 0 of Set 8 | broome
# Processing Record 1 of Set 8 | yagry
# City not found. Skipping...
# Processing Record 2 of Set 8 | verkhniy baskunchak
# Processing Record 3 of Set 8 | luanda
# Processing Record 4 of Set 8 | suntar
# Processing Record 5 of Set 8 | krasnovishersk
# Processing Record 6 of Set 8 | dalandzadgad
# Processing Record 7 of Set 8 | rudnyy
# Processing Record 8 of Set 8 | canarana
# Processing Record 9 of Set 8 | margate
# Processing Record 10 of Set 8 | debre mark'os
# Processing Record 11 of Set 8 | vila franca do campo
# Processing Record 12 of Set 8 | papao
# Processing Record 13 of Set 8 | colonia
# Processing Record 14 of Set 8 | ust-nera
# Processing Record 15 of Set 8 | mercedes
# Processing Record 16 of Set 8 | chinde
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | ambodifotatra
# Processing Record 19 of Set 8 | ixtapa
# Processing Record 20 of Set 8 | gulf shores
# Processing Record 21 of Set 8 | carloforte
# Processing Record 22 of Set 8 | cudillero
# Processing Record 23 of Set 8 | lethem
# Processing Record 24 of Set 8 | kavieng
# Processing Record 25 of Set 8 | zangguy
# City not found. Skipping...
# Processing Record 26 of Set 8 | horta
# Processing Record 27 of Set 8 | grand-bassam
# Processing Record 28 of Set 8 | santa terezinha
# Processing Record 29 of Set 8 | visby
# Processing Record 30 of Set 8 | tudela
# Processing Record 31 of Set 8 | itoman
# Processing Record 32 of Set 8 | urangan
# Processing Record 33 of Set 8 | cabedelo
# Processing Record 34 of Set 8 | jaguarao
# Processing Record 35 of Set 8 | la libertad
# Processing Record 36 of Set 8 | timaru
# Processing Record 37 of Set 8 | 'alaqahdari dishu
# Processing Record 38 of Set 8 | qarazhal
# Processing Record 39 of Set 8 | muana
# Processing Record 40 of Set 8 | dunedin
# Processing Record 41 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 8 | moapa valley
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | manismata
# Processing Record 45 of Set 8 | pemba
# Processing Record 46 of Set 8 | el jadid
# Processing Record 47 of Set 8 | lodja
# Processing Record 48 of Set 8 | yacuiba
# Processing Record 49 of Set 8 | al burayqah
# Processing Record 0 of Set 9 | tamanrasset
# Processing Record 1 of Set 9 | bafoulabe
# Processing Record 2 of Set 9 | tanjung selor
# City not found. Skipping...
# Processing Record 3 of Set 9 | necochea
# Processing Record 4 of Set 9 | hell-ville
# Processing Record 5 of Set 9 | kargasok
# Processing Record 6 of Set 9 | kyenjojo
# Processing Record 7 of Set 9 | sittwe
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | severo-yeniseyskiy
# Processing Record 10 of Set 9 | san antonio de pale
# Processing Record 11 of Set 9 | azul
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | mukalla
# Processing Record 14 of Set 9 | rio grande
# Processing Record 15 of Set 9 | languyan
# Processing Record 16 of Set 9 | kyren
# Processing Record 17 of Set 9 | dhidhdhoo
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | mukah
# City not found. Skipping...
# Processing Record 20 of Set 9 | crane
# Processing Record 21 of Set 9 | sakakah
# Processing Record 22 of Set 9 | preobrazheniye
# Processing Record 23 of Set 9 | roseburg north
# Processing Record 24 of Set 9 | salaverry
# Processing Record 25 of Set 9 | choele choel
# Processing Record 26 of Set 9 | kibre mengist
# Processing Record 27 of Set 9 | fonte boa
# Processing Record 28 of Set 9 | ridgecrest
# Processing Record 29 of Set 9 | ceerigaabo
# Processing Record 30 of Set 9 | posto fiscal rolim de moura
# Processing Record 31 of Set 9 | saint-francois
# Processing Record 32 of Set 9 | santa ana
# Processing Record 33 of Set 9 | tuy hoa
# Processing Record 34 of Set 9 | chiili
# City not found. Skipping...
# Processing Record 35 of Set 9 | cabo san lucas
# Processing Record 36 of Set 9 | lake ridge
# Processing Record 37 of Set 9 | salmas
# Processing Record 38 of Set 9 | jackson
# Processing Record 39 of Set 9 | santa helena
# Processing Record 40 of Set 9 | road town
# Processing Record 41 of Set 9 | krasnyy chikoy
# Processing Record 42 of Set 9 | st. john's
# Processing Record 43 of Set 9 | acajutla
# Processing Record 44 of Set 9 | holualoa
# Processing Record 45 of Set 9 | yenisehir
# Processing Record 46 of Set 9 | arevalo
# Processing Record 47 of Set 9 | mikhaylovskoye
# Processing Record 48 of Set 9 | am timan
# Processing Record 49 of Set 9 | hadibu
# Processing Record 0 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 1 of Set 10 | capitao poco
# Processing Record 2 of Set 10 | cestos city
# Processing Record 3 of Set 10 | el dorado
# Processing Record 4 of Set 10 | dudinka
# Processing Record 5 of Set 10 | aqadyr
# Processing Record 6 of Set 10 | obihiro
# Processing Record 7 of Set 10 | smithers
# Processing Record 8 of Set 10 | prince george
# Processing Record 9 of Set 10 | ustka
# Processing Record 10 of Set 10 | lagoa
# Processing Record 11 of Set 10 | birnin kebbi
# Processing Record 12 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 13 of Set 10 | oktyabr'skiy
# Processing Record 14 of Set 10 | inarajan village
# Processing Record 15 of Set 10 | sarpol-e zahab
# Processing Record 16 of Set 10 | khovd
# Processing Record 17 of Set 10 | lamu
# Processing Record 18 of Set 10 | itaituba
# Processing Record 19 of Set 10 | sandnessjoen
# Processing Record 20 of Set 10 | aasiaat
# Processing Record 21 of Set 10 | burela de cabo
# Processing Record 22 of Set 10 | lemvig
# Processing Record 23 of Set 10 | kangding
# Processing Record 24 of Set 10 | puerto padre
# Processing Record 25 of Set 10 | piti village
# Processing Record 26 of Set 10 | la paz
# Processing Record 27 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 28 of Set 10 | mananara
# Processing Record 29 of Set 10 | alamosa
# Processing Record 30 of Set 10 | ulladulla
# Processing Record 31 of Set 10 | sabha
# Processing Record 32 of Set 10 | tobruk
# Processing Record 33 of Set 10 | nichinan
# Processing Record 34 of Set 10 | sao felix do xingu
# Processing Record 35 of Set 10 | jepelacio
# Processing Record 36 of Set 10 | kisangani
# Processing Record 37 of Set 10 | morondava
# Processing Record 38 of Set 10 | wewak
# Processing Record 39 of Set 10 | guelmim
# Processing Record 40 of Set 10 | el naranjo
# Processing Record 41 of Set 10 | yuci
# Processing Record 42 of Set 10 | amga
# Processing Record 43 of Set 10 | arkhangel'sk
# Processing Record 44 of Set 10 | villa regina
# Processing Record 45 of Set 10 | barah
# Processing Record 46 of Set 10 | fale old settlement
# Processing Record 47 of Set 10 | hadithah
# Processing Record 48 of Set 10 | fuling
# Processing Record 49 of Set 10 | popondetta
# Processing Record 0 of Set 11 | midwest city
# Processing Record 1 of Set 11 | bubaque
# Processing Record 2 of Set 11 | ponta delgada
# Processing Record 3 of Set 11 | monahans
# Processing Record 4 of Set 11 | zabol
# Processing Record 5 of Set 11 | nadym
# Processing Record 6 of Set 11 | alofi
# Processing Record 7 of Set 11 | nabire
# Processing Record 8 of Set 11 | santa cruz cabralia
# Processing Record 9 of Set 11 | hammerfest
# Processing Record 10 of Set 11 | palmer
# Processing Record 11 of Set 11 | kamoke
# Processing Record 12 of Set 11 | sur
# Processing Record 13 of Set 11 | richards bay
# Processing Record 14 of Set 11 | gueltat zemmour
# City not found. Skipping...
# Processing Record 15 of Set 11 | spas-klepiki
# Processing Record 16 of Set 11 | patterson
# Processing Record 17 of Set 11 | port-vila
# Processing Record 18 of Set 11 | egilsstadir
# Processing Record 19 of Set 11 | guerrero
# Processing Record 20 of Set 11 | suva
# Processing Record 21 of Set 11 | aver-o-mar
# Processing Record 22 of Set 11 | sirte
# Processing Record 23 of Set 11 | portland
# Processing Record 24 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 25 of Set 11 | engel's
# Processing Record 26 of Set 11 | santa cruz
# Processing Record 27 of Set 11 | thunder bay
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | port pirie
# Processing Record 30 of Set 11 | garcia
# Processing Record 31 of Set 11 | myitkyina
# Processing Record 32 of Set 11 | mek'ele
# Processing Record 33 of Set 11 | poronaysk
# Processing Record 34 of Set 11 | mejit
# Processing Record 35 of Set 11 | lakatoro
# Processing Record 36 of Set 11 | kalampaka
# Processing Record 37 of Set 11 | morant bay
# Processing Record 38 of Set 11 | dalianwan
# Processing Record 39 of Set 11 | yaypan
# Processing Record 40 of Set 11 | shatrovo
# Processing Record 41 of Set 11 | mao
# Processing Record 42 of Set 11 | ghormach
# Processing Record 43 of Set 11 | luanco
# Processing Record 44 of Set 11 | paciran
# Processing Record 45 of Set 11 | la'ie
# Processing Record 46 of Set 11 | serhetabat
# Processing Record 47 of Set 11 | huaidian
# Processing Record 48 of Set 11 | goderich
# Processing Record 49 of Set 11 | saldanha
# Processing Record 0 of Set 12 | kununurra
# Processing Record 1 of Set 12 | guerrero negro
# Processing Record 2 of Set 12 | lubang
# Processing Record 3 of Set 12 | constantia
# Processing Record 4 of Set 12 | merizo village
# Processing Record 5 of Set 12 | trinidad
# Processing Record 6 of Set 12 | mandideep
# Processing Record 7 of Set 12 | bhimunipatnam
# Processing Record 8 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 12 | baykal'sk
# Processing Record 10 of Set 12 | kamennogorsk
# Processing Record 11 of Set 12 | as sulayyil
# Processing Record 12 of Set 12 | la passe
# Processing Record 13 of Set 12 | black point
# Processing Record 14 of Set 12 | jijiga
# Processing Record 15 of Set 12 | shaoguan
# Processing Record 16 of Set 12 | al matariyah
# Processing Record 17 of Set 12 | taulaga
# Processing Record 18 of Set 12 | harper
# Processing Record 19 of Set 12 | raton
# Processing Record 20 of Set 12 | bobbili
# Processing Record 21 of Set 12 | belo sur tsiribihina
# Processing Record 22 of Set 12 | la sarre
# Processing Record 23 of Set 12 | nouadhibou
# Processing Record 24 of Set 12 | ayorou
# Processing Record 25 of Set 12 | argostolion
# Processing Record 26 of Set 12 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 27 of Set 12 | kavaratti
# Processing Record 28 of Set 12 | zakamensk
# Processing Record 29 of Set 12 | howard springs
# Processing Record 30 of Set 12 | sechura
# Processing Record 31 of Set 12 | gucheng chengguanzhen
# Processing Record 32 of Set 12 | inhambane
# Processing Record 33 of Set 12 | matoury
# Processing Record 34 of Set 12 | le port
# Processing Record 35 of Set 12 | iringa
# Processing Record 36 of Set 12 | zhaqsy
# Processing Record 37 of Set 12 | teodoro sampaio
# Processing Record 38 of Set 12 | parral
# Processing Record 39 of Set 12 | hoi an
# Processing Record 40 of Set 12 | minab
# Processing Record 41 of Set 12 | governor's harbour
# City not found. Skipping...
# Processing Record 42 of Set 12 | dubove
# Processing Record 43 of Set 12 | diego de almagro
# Processing Record 44 of Set 12 | limbdi
# Processing Record 45 of Set 12 | port isabel
# Processing Record 46 of Set 12 | dawson creek
# Processing Record 47 of Set 12 | kroya
# Processing Record 48 of Set 12 | adre
# Processing Record 49 of Set 12 | anchorage
# Processing Record 0 of Set 13 | saratamata
# City not found. Skipping...
# Processing Record 1 of Set 13 | revda
# Processing Record 2 of Set 13 | sinjai
# Processing Record 3 of Set 13 | beyneu
# Processing Record 4 of Set 13 | masterton
# Processing Record 5 of Set 13 | bondo
# Processing Record 6 of Set 13 | ziway
# Processing Record 7 of Set 13 | quellon
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | eloy
# Processing Record 10 of Set 13 | tambopata
# Processing Record 11 of Set 13 | ajdabiya
# Processing Record 12 of Set 13 | whitby
# Processing Record 13 of Set 13 | hafar al-batin
# Processing Record 14 of Set 13 | okha
# Processing Record 15 of Set 13 | jiexiu
# Processing Record 16 of Set 13 | ad darb
# Processing Record 17 of Set 13 | stephenville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          587
# Lat           587
# Lng           587
# Max Temp      587
# Humidity      587
# Cloudiness    587
# Wind Speed    587
# Country       587
# Date          587
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                    dahlonega  34.5326  -83.9849     27.66        89
# 1  edinburgh of the seven seas -37.0676  -12.3116     12.24        74
# 2                     waitangi -43.9535 -176.5597      8.79        88
# 3                    guarapari -20.6667  -40.4975     22.72        89
# 4                  nar'yan-mar  67.6713   53.0870      6.11        93
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        2.14      US  1692670688
# 1         100        3.28      SH  1692670733
# 2         100        4.47      NZ  1692670734
# 3          51        2.44      BR  1692670734
# 4          85        3.22      RU  1692670734

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          dahlonega  34.5326  -83.9849     27.66        89
# 1        edinburgh of the seven seas -37.0676  -12.3116     12.24        74
# 2                           waitangi -43.9535 -176.5597      8.79        88
# 3                          guarapari -20.6667  -40.4975     22.72        89
# 4                        nar'yan-mar  67.6713   53.0870      6.11        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        2.14      US  1692670688
# 1               100        3.28      SH  1692670733
# 2               100        4.47      NZ  1692670734
# 3                51        2.44      BR  1692670734
# 4                85        3.22      RU  1692670734

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Max Temp"], facecolors = "#069AF3", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature (2023-07-24)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Humidity"], facecolors = "#069AF3", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-07-24)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Cloudiness"], facecolors = "#069AF3", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-07-24)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df.loc[:,"Lat"], city_data_df.loc[:,"Wind Speed"], facecolors = "#069AF3", edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-07-24)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_plot(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    regress_plot.line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          dahlonega  34.5326  -83.9849     27.66        89         100
# 4        nar'yan-mar  67.6713   53.0870      6.11        93          85
# 5              altay  47.8667   88.1167     22.30        35           0
# 6           klaksvik  62.2266   -6.5890     13.51        99         100
# 9             chaihe  44.7667  129.7000     23.61        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.14      US  1692670688
# 4              3.22      RU  1692670734
# 5              1.24      CN  1692670783
# 6              8.58      FO  1692670784
# 9              5.24      CN  1692670785

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]


# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
regress_plot(northern_hemi_df.loc[:, "Lat"], northern_hemi_df.loc[:,"Max Temp"])
plt.annotate(regress_plot.line_eq,(2,4),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Northern Hemisphere")
plt.show()

# %%
# Linear regression on Southern Hemisphere
regress_plot(southern_hemi_df.loc[:, "Lat"], southern_hemi_df.loc[:,"Max Temp"])
plt.annotate(regress_plot.line_eq,(-25,0),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df.loc[:, "Lat"], northern_hemi_df.loc[:,"Humidity"])
plt.annotate(regress_plot.line_eq,(45,6),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df.loc[:, "Lat"], southern_hemi_df.loc[:,"Humidity"])
plt.annotate(regress_plot.line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** By comparing the scatter plots of Humidity versus Latitude, we observe that there is a weak correlation between the two values.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df.loc[:, "Lat"], northern_hemi_df.loc[:,"Cloudiness"])
plt.annotate(regress_plot.line_eq,(2,4),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df.loc[:, "Lat"], southern_hemi_df.loc[:,"Cloudiness"])
plt.annotate(regress_plot.line_eq,(-55,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** When comparing the scatter plots of Cloudiness versus Latitude, it is observed that there is a weak correlation with very little correlation in the northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plot(northern_hemi_df.loc[:, "Lat"], northern_hemi_df.loc[:,"Wind Speed"])
plt.annotate(regress_plot.line_eq,(30,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere")
plt.show()

# %%
# Southern Hemisphere
regress_plot(southern_hemi_df.loc[:, "Lat"], southern_hemi_df.loc[:,"Wind Speed"])
plt.annotate(regress_plot.line_eq,(-30,14),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** When looking at the scatter plots for wind speed and latitude, there is once again a weak correlation between the two values. There is almost no correlation in the southern hemisphere.
